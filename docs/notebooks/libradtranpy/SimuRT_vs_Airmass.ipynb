# %% [markdown]
# # Simulate transparency vs airmass at LSST
# =======================================================================
#
#
# - Sylvie Dagoret-Campagne
# - affliliation : IJCLAB/IN2P3/CNRS
# - creation date :  24 February 2020
# - last update : October 22th 2023
#
# =======================================================================

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import sys
import os
import numpy as np

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.cm as cmx

# %%
matplotlib.rcParams.update({'font.size': 15, 'lines.linewidth': 2, 'lines.markersize': 15})
matplotlib.rcParams["axes.labelsize"]="small"
matplotlib.rcParams["axes.linewidth"]=2.0
matplotlib.rcParams["xtick.major.size"]=8
matplotlib.rcParams["ytick.major.size"]=8
matplotlib.rcParams["ytick.minor.size"]=5
matplotlib.rcParams["xtick.labelsize"]="large"
matplotlib.rcParams["ytick.labelsize"]="large"
matplotlib.rcParams["figure.figsize"]=(12,6)
matplotlib.rcParams['axes.titlesize'] = 15
matplotlib.rcParams['axes.titleweight'] = 'bold'
#matplotlib.rcParams['axes.facecolor'] = 'blue'
matplotlib.rcParams['xtick.direction'] = 'out'
matplotlib.rcParams['ytick.direction'] = 'out'
matplotlib.rcParams['lines.markeredgewidth'] = 0.3 # the line width around the marker symbol
matplotlib.rcParams['lines.markersize'] = 10  # markersize, in points
matplotlib.rcParams['grid.alpha'] = 1. # transparency, between 0.0 and 1.0
matplotlib.rcParams['grid.linestyle'] = '-' # simple line
matplotlib.rcParams['grid.linewidth'] = 0.4 # in points

# %%
from scipy.interpolate import interp1d

# %%
from libradtranpy import libsimulateVisible
# Out:
# libradtranpath= /Users/dagoret/MacOSX/External/libRadtran/

# %%
os.getenv('LIBRADTRANDIR')
# Out:
# '/Users/dagoret/MacOSX/External/libRadtran'

# %%
AMMIN=1
AMMAX=3.1
AMSTEP = 0.1
all_am=np.arange(AMMIN,AMMAX,AMSTEP)
pressure = 0. # use default value
pwv=4.0
aer=0
ozone=300.
cloudext=0

# %%
NBOBS=len(all_am)

# %%
jet = plt.get_cmap('jet')
cNorm = colors.Normalize(vmin=0, vmax=NBOBS)
scalarMap = cmx.ScalarMappable(norm=cNorm, cmap=jet)
all_colors = scalarMap.to_rgba(np.arange( NBOBS), alpha=1)

# %%
all_trans = []
for index in np.arange(NBOBS):
    am = all_am[index]
    print(f"simulate index = {index}, airmass = {am:.2f}")
    path,thefile=libsimulateVisible.ProcessSimulation(am,pwv,ozone,pressure,
                                                      prof_str='us',proc_str='sa',cloudext=cloudext,altitude_str="LSST")
    data = np.loadtxt(os.path.join(path,thefile))
    wl = data[:,0]
    atm = data[:,1] 
    all_trans.append(atm)
# Out:
# simulate index = 0, airmass = 1.00
# --------------- ProcessSimulation -----------------------------
#  1) airmass =  1.0
#  2) pwv =  4.0
#  3) oz =  300.0
#  4) pressure  =  0.0
#  5) atmospheric profile =  us
#  6) interaction processes =  sa
#  7) cloud extinction =  0
#  8) site or altitude =  LSST
# --------------------------------------------
# Dict_Of_sitesAltitudes.get(altitude_str) =  2.663
# Observation site altitude for libradran sim : 2.663 km
# Running uvspec with input file:  simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/in/RT_LS_pp_us_sa_rtvis_z10_wv40_oz30_cld0000.INP
# Output to file                :  simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/out/RT_LS_pp_us_sa_rtvis_z10_wv40_oz30_cld0000.OUT
# Path to exec                :  /Users/dagoret/MacOSX/External/libRadtran/
# uvspec cmd:  /Users/dagoret/MacOSX/External/libRadtran/bin/uvspec  < simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/in/RT_LS_pp_us_sa_rtvis_z10_wv40_oz30_cld0000.INP > simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/out/RT_LS_pp_us_sa_rtvis_z10_wv40_oz30_cld0000.OUT
# simulate index = 1, airmass = 1.10
# --------------- ProcessSimulation -----------------------------
#  1) airmass =  1.1
#  2) pwv =  4.0
#  3) oz =  300.0
#  4) pressure  =  0.0
#  5) atmospheric profile =  us
#  6) interaction processes =  sa
#  7) cloud extinction =  0
#  8) site or altitude =  LSST
# --------------------------------------------
# Dict_Of_sitesAltitudes.get(altitude_str) =  2.663
# Observation site altitude for libradran sim : 2.663 km
# Running uvspec with input file:  simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/in/RT_LS_pp_us_sa_rtvis_z11_wv40_oz30_cld0000.INP
# Output to file                :  simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/out/RT_LS_pp_us_sa_rtvis_z11_wv40_oz30_cld0000.OUT
# Path to exec                :  /Users/dagoret/MacOSX/External/libRadtran/
# uvspec cmd:  /Users/dagoret/MacOSX/External/libRadtran/bin/uvspec  < simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/in/RT_LS_pp_us_sa_rtvis_z11_wv40_oz30_cld0000.INP > simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/out/RT_LS_pp_us_sa_rtvis_z11_wv40_oz30_cld0000.OUT
# simulate index = 2, airmass = 1.20
# --------------- ProcessSimulation -----------------------------
#  1) airmass =  1.2000000000000002
#  2) pwv =  4.0
#  3) oz =  300.0
#  4) pressure  =  0.0
#  5) atmospheric profile =  us
#  6) interaction processes =  sa
#  7) cloud extinction =  0
#  8) site or altitude =  LSST
# --------------------------------------------
# Dict_Of_sitesAltitudes.get(altitude_str) =  2.663
# Observation site altitude for libradran sim : 2.663 km
# Running uvspec with input file:  simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/in/RT_LS_pp_us_sa_rtvis_z12_wv40_oz30_cld0000.INP
# Output to file                :  simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/out/RT_LS_pp_us_sa_rtvis_z12_wv40_oz30_cld0000.OUT
# Path to exec                :  /Users/dagoret/MacOSX/External/libRadtran/
# uvspec cmd:  /Users/dagoret/MacOSX/External/libRadtran/bin/uvspec  < simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/in/RT_LS_pp_us_sa_rtvis_z12_wv40_oz30_cld0000.INP > simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/out/RT_LS_pp_us_sa_rtvis_z12_wv40_oz30_cld0000.OUT
# simulate index = 3, airmass = 1.30
# --------------- ProcessSimulation -----------------------------
#  1) airmass =  1.3000000000000003
#  2) pwv =  4.0
#  3) oz =  300.0
#  4) pressure  =  0.0
#  5) atmospheric profile =  us
#  6) interaction processes =  sa
#  7) cloud extinction =  0
#  8) site or altitude =  LSST
# --------------------------------------------
# Dict_Of_sitesAltitudes.get(altitude_str) =  2.663
# Observation site altitude for libradran sim : 2.663 km
# Running uvspec with input file:  simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/in/RT_LS_pp_us_sa_rtvis_z13_wv40_oz30_cld0000.INP
# Output to file                :  simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/out/RT_LS_pp_us_sa_rtvis_z13_wv40_oz30_cld0000.OUT
# Path to exec                :  /Users/dagoret/MacOSX/External/libRadtran/
# uvspec cmd:  /Users/dagoret/MacOSX/External/libRadtran/bin/uvspec  < simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/in/RT_LS_pp_us_sa_rtvis_z13_wv40_oz30_cld0000.INP > simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/out/RT_LS_pp_us_sa_rtvis_z13_wv40_oz30_cld0000.OUT
# simulate index = 4, airmass = 1.40
# --------------- ProcessSimulation -----------------------------
#  1) airmass =  1.4000000000000004
#  2) pwv =  4.0
#  3) oz =  300.0
#  4) pressure  =  0.0
#  5) atmospheric profile =  us
#  6) interaction processes =  sa
#  7) cloud extinction =  0
#  8) site or altitude =  LSST
# --------------------------------------------
# Dict_Of_sitesAltitudes.get(altitude_str) =  2.663
# Observation site altitude for libradran sim : 2.663 km
# Running uvspec with input file:  simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/in/RT_LS_pp_us_sa_rtvis_z14_wv40_oz30_cld0000.INP
# Output to file                :  simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/out/RT_LS_pp_us_sa_rtvis_z14_wv40_oz30_cld0000.OUT
# Path to exec                :  /Users/dagoret/MacOSX/External/libRadtran/
# uvspec cmd:  /Users/dagoret/MacOSX/External/libRadtran/bin/uvspec  < simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/in/RT_LS_pp_us_sa_rtvis_z14_wv40_oz30_cld0000.INP > simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/out/RT_LS_pp_us_sa_rtvis_z14_wv40_oz30_cld0000.OUT
# simulate index = 5, airmass = 1.50
# --------------- ProcessSimulation -----------------------------
#  1) airmass =  1.5000000000000004
#  2) pwv =  4.0
#  3) oz =  300.0
#  4) pressure  =  0.0
#  5) atmospheric profile =  us
#  6) interaction processes =  sa
#  7) cloud extinction =  0
#  8) site or altitude =  LSST
# --------------------------------------------
# Dict_Of_sitesAltitudes.get(altitude_str) =  2.663
# Observation site altitude for libradran sim : 2.663 km
# Running uvspec with input file:  simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/in/RT_LS_pp_us_sa_rtvis_z15_wv40_oz30_cld0000.INP
# Output to file                :  simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/out/RT_LS_pp_us_sa_rtvis_z15_wv40_oz30_cld0000.OUT
# Path to exec                :  /Users/dagoret/MacOSX/External/libRadtran/
# uvspec cmd:  /Users/dagoret/MacOSX/External/libRadtran/bin/uvspec  < simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/in/RT_LS_pp_us_sa_rtvis_z15_wv40_oz30_cld0000.INP > simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/out/RT_LS_pp_us_sa_rtvis_z15_wv40_oz30_cld0000.OUT
# simulate index = 6, airmass = 1.60
# --------------- ProcessSimulation -----------------------------
#  1) airmass =  1.6000000000000005
#  2) pwv =  4.0
#  3) oz =  300.0
#  4) pressure  =  0.0
#  5) atmospheric profile =  us
#  6) interaction processes =  sa
#  7) cloud extinction =  0
#  8) site or altitude =  LSST
# --------------------------------------------
# Dict_Of_sitesAltitudes.get(altitude_str) =  2.663
# Observation site altitude for libradran sim : 2.663 km
# Running uvspec with input file:  simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/in/RT_LS_pp_us_sa_rtvis_z16_wv40_oz30_cld0000.INP
# Output to file                :  simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/out/RT_LS_pp_us_sa_rtvis_z16_wv40_oz30_cld0000.OUT
# Path to exec                :  /Users/dagoret/MacOSX/External/libRadtran/
# uvspec cmd:  /Users/dagoret/MacOSX/External/libRadtran/bin/uvspec  < simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/in/RT_LS_pp_us_sa_rtvis_z16_wv40_oz30_cld0000.INP > simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/out/RT_LS_pp_us_sa_rtvis_z16_wv40_oz30_cld0000.OUT
# simulate index = 7, airmass = 1.70
# --------------- ProcessSimulation -----------------------------
#  1) airmass =  1.7000000000000006
#  2) pwv =  4.0
#  3) oz =  300.0
#  4) pressure  =  0.0
#  5) atmospheric profile =  us
#  6) interaction processes =  sa
#  7) cloud extinction =  0
#  8) site or altitude =  LSST
# --------------------------------------------
# Dict_Of_sitesAltitudes.get(altitude_str) =  2.663
# Observation site altitude for libradran sim : 2.663 km
# Running uvspec with input file:  simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/in/RT_LS_pp_us_sa_rtvis_z17_wv40_oz30_cld0000.INP
# Output to file                :  simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/out/RT_LS_pp_us_sa_rtvis_z17_wv40_oz30_cld0000.OUT
# Path to exec                :  /Users/dagoret/MacOSX/External/libRadtran/
# uvspec cmd:  /Users/dagoret/MacOSX/External/libRadtran/bin/uvspec  < simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/in/RT_LS_pp_us_sa_rtvis_z17_wv40_oz30_cld0000.INP > simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/out/RT_LS_pp_us_sa_rtvis_z17_wv40_oz30_cld0000.OUT
# simulate index = 8, airmass = 1.80
# --------------- ProcessSimulation -----------------------------
#  1) airmass =  1.8000000000000007
#  2) pwv =  4.0
#  3) oz =  300.0
#  4) pressure  =  0.0
#  5) atmospheric profile =  us
#  6) interaction processes =  sa
#  7) cloud extinction =  0
#  8) site or altitude =  LSST
# --------------------------------------------
# Dict_Of_sitesAltitudes.get(altitude_str) =  2.663
# Observation site altitude for libradran sim : 2.663 km
# Running uvspec with input file:  simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/in/RT_LS_pp_us_sa_rtvis_z18_wv40_oz30_cld0000.INP
# Output to file                :  simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/out/RT_LS_pp_us_sa_rtvis_z18_wv40_oz30_cld0000.OUT
# Path to exec                :  /Users/dagoret/MacOSX/External/libRadtran/
# uvspec cmd:  /Users/dagoret/MacOSX/External/libRadtran/bin/uvspec  < simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/in/RT_LS_pp_us_sa_rtvis_z18_wv40_oz30_cld0000.INP > simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/out/RT_LS_pp_us_sa_rtvis_z18_wv40_oz30_cld0000.OUT
# simulate index = 9, airmass = 1.90
# --------------- ProcessSimulation -----------------------------
#  1) airmass =  1.9000000000000008
#  2) pwv =  4.0
#  3) oz =  300.0
#  4) pressure  =  0.0
#  5) atmospheric profile =  us
#  6) interaction processes =  sa
#  7) cloud extinction =  0
#  8) site or altitude =  LSST
# --------------------------------------------
# Dict_Of_sitesAltitudes.get(altitude_str) =  2.663
# Observation site altitude for libradran sim : 2.663 km
# Running uvspec with input file:  simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/in/RT_LS_pp_us_sa_rtvis_z19_wv40_oz30_cld0000.INP
# Output to file                :  simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/out/RT_LS_pp_us_sa_rtvis_z19_wv40_oz30_cld0000.OUT
# Path to exec                :  /Users/dagoret/MacOSX/External/libRadtran/
# uvspec cmd:  /Users/dagoret/MacOSX/External/libRadtran/bin/uvspec  < simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/in/RT_LS_pp_us_sa_rtvis_z19_wv40_oz30_cld0000.INP > simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/out/RT_LS_pp_us_sa_rtvis_z19_wv40_oz30_cld0000.OUT
# simulate index = 10, airmass = 2.00
# --------------- ProcessSimulation -----------------------------
#  1) airmass =  2.000000000000001
#  2) pwv =  4.0
#  3) oz =  300.0
#  4) pressure  =  0.0
#  5) atmospheric profile =  us
#  6) interaction processes =  sa
#  7) cloud extinction =  0
#  8) site or altitude =  LSST
# --------------------------------------------
# Dict_Of_sitesAltitudes.get(altitude_str) =  2.663
# Observation site altitude for libradran sim : 2.663 km
# Running uvspec with input file:  simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/in/RT_LS_pp_us_sa_rtvis_z20_wv40_oz30_cld0000.INP
# Output to file                :  simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/out/RT_LS_pp_us_sa_rtvis_z20_wv40_oz30_cld0000.OUT
# Path to exec                :  /Users/dagoret/MacOSX/External/libRadtran/
# uvspec cmd:  /Users/dagoret/MacOSX/External/libRadtran/bin/uvspec  < simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/in/RT_LS_pp_us_sa_rtvis_z20_wv40_oz30_cld0000.INP > simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/out/RT_LS_pp_us_sa_rtvis_z20_wv40_oz30_cld0000.OUT
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
# ...
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# ******* WARNING >>>>>>
#  SETDIS--beam angle=computational angle;
#  ******* changing cosine of solar zenith angle, umu0, from  0.500000 to 0.500055
# simulate index = 11, airmass = 2.10
# --------------- ProcessSimulation -----------------------------
#  1) airmass =  2.100000000000001
#  2) pwv =  4.0
#  3) oz =  300.0
#  4) pressure  =  0.0
#  5) atmospheric profile =  us
#  6) interaction processes =  sa
#  7) cloud extinction =  0
#  8) site or altitude =  LSST
# --------------------------------------------
# Dict_Of_sitesAltitudes.get(altitude_str) =  2.663
# Observation site altitude for libradran sim : 2.663 km
# Running uvspec with input file:  simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/in/RT_LS_pp_us_sa_rtvis_z21_wv40_oz30_cld0000.INP
# Output to file                :  simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/out/RT_LS_pp_us_sa_rtvis_z21_wv40_oz30_cld0000.OUT
# Path to exec                :  /Users/dagoret/MacOSX/External/libRadtran/
# uvspec cmd:  /Users/dagoret/MacOSX/External/libRadtran/bin/uvspec  < simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/in/RT_LS_pp_us_sa_rtvis_z21_wv40_oz30_cld0000.INP > simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/out/RT_LS_pp_us_sa_rtvis_z21_wv40_oz30_cld0000.OUT
# simulate index = 12, airmass = 2.20
# --------------- ProcessSimulation -----------------------------
#  1) airmass =  2.200000000000001
#  2) pwv =  4.0
#  3) oz =  300.0
#  4) pressure  =  0.0
#  5) atmospheric profile =  us
#  6) interaction processes =  sa
#  7) cloud extinction =  0
#  8) site or altitude =  LSST
# --------------------------------------------
# Dict_Of_sitesAltitudes.get(altitude_str) =  2.663
# Observation site altitude for libradran sim : 2.663 km
# Running uvspec with input file:  simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/in/RT_LS_pp_us_sa_rtvis_z22_wv40_oz30_cld0000.INP
# Output to file                :  simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/out/RT_LS_pp_us_sa_rtvis_z22_wv40_oz30_cld0000.OUT
# Path to exec                :  /Users/dagoret/MacOSX/External/libRadtran/
# uvspec cmd:  /Users/dagoret/MacOSX/External/libRadtran/bin/uvspec  < simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/in/RT_LS_pp_us_sa_rtvis_z22_wv40_oz30_cld0000.INP > simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/out/RT_LS_pp_us_sa_rtvis_z22_wv40_oz30_cld0000.OUT
# simulate index = 13, airmass = 2.30
# --------------- ProcessSimulation -----------------------------
#  1) airmass =  2.300000000000001
#  2) pwv =  4.0
#  3) oz =  300.0
#  4) pressure  =  0.0
#  5) atmospheric profile =  us
#  6) interaction processes =  sa
#  7) cloud extinction =  0
#  8) site or altitude =  LSST
# --------------------------------------------
# Dict_Of_sitesAltitudes.get(altitude_str) =  2.663
# Observation site altitude for libradran sim : 2.663 km
# Running uvspec with input file:  simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/in/RT_LS_pp_us_sa_rtvis_z23_wv40_oz30_cld0000.INP
# Output to file                :  simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/out/RT_LS_pp_us_sa_rtvis_z23_wv40_oz30_cld0000.OUT
# Path to exec                :  /Users/dagoret/MacOSX/External/libRadtran/
# uvspec cmd:  /Users/dagoret/MacOSX/External/libRadtran/bin/uvspec  < simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/in/RT_LS_pp_us_sa_rtvis_z23_wv40_oz30_cld0000.INP > simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/out/RT_LS_pp_us_sa_rtvis_z23_wv40_oz30_cld0000.OUT
# simulate index = 14, airmass = 2.40
# --------------- ProcessSimulation -----------------------------
#  1) airmass =  2.4000000000000012
#  2) pwv =  4.0
#  3) oz =  300.0
#  4) pressure  =  0.0
#  5) atmospheric profile =  us
#  6) interaction processes =  sa
#  7) cloud extinction =  0
#  8) site or altitude =  LSST
# --------------------------------------------
# Dict_Of_sitesAltitudes.get(altitude_str) =  2.663
# Observation site altitude for libradran sim : 2.663 km
# Running uvspec with input file:  simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/in/RT_LS_pp_us_sa_rtvis_z24_wv40_oz30_cld0000.INP
# Output to file                :  simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/out/RT_LS_pp_us_sa_rtvis_z24_wv40_oz30_cld0000.OUT
# Path to exec                :  /Users/dagoret/MacOSX/External/libRadtran/
# uvspec cmd:  /Users/dagoret/MacOSX/External/libRadtran/bin/uvspec  < simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/in/RT_LS_pp_us_sa_rtvis_z24_wv40_oz30_cld0000.INP > simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/out/RT_LS_pp_us_sa_rtvis_z24_wv40_oz30_cld0000.OUT
# simulate index = 15, airmass = 2.50
# --------------- ProcessSimulation -----------------------------
#  1) airmass =  2.5000000000000013
#  2) pwv =  4.0
#  3) oz =  300.0
#  4) pressure  =  0.0
#  5) atmospheric profile =  us
#  6) interaction processes =  sa
#  7) cloud extinction =  0
#  8) site or altitude =  LSST
# --------------------------------------------
# Dict_Of_sitesAltitudes.get(altitude_str) =  2.663
# Observation site altitude for libradran sim : 2.663 km
# Running uvspec with input file:  simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/in/RT_LS_pp_us_sa_rtvis_z25_wv40_oz30_cld0000.INP
# Output to file                :  simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/out/RT_LS_pp_us_sa_rtvis_z25_wv40_oz30_cld0000.OUT
# Path to exec                :  /Users/dagoret/MacOSX/External/libRadtran/
# uvspec cmd:  /Users/dagoret/MacOSX/External/libRadtran/bin/uvspec  < simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/in/RT_LS_pp_us_sa_rtvis_z25_wv40_oz30_cld0000.INP > simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/out/RT_LS_pp_us_sa_rtvis_z25_wv40_oz30_cld0000.OUT
# simulate index = 16, airmass = 2.60
# --------------- ProcessSimulation -----------------------------
#  1) airmass =  2.6000000000000014
#  2) pwv =  4.0
#  3) oz =  300.0
#  4) pressure  =  0.0
#  5) atmospheric profile =  us
#  6) interaction processes =  sa
#  7) cloud extinction =  0
#  8) site or altitude =  LSST
# --------------------------------------------
# Dict_Of_sitesAltitudes.get(altitude_str) =  2.663
# Observation site altitude for libradran sim : 2.663 km
# Running uvspec with input file:  simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/in/RT_LS_pp_us_sa_rtvis_z26_wv40_oz30_cld0000.INP
# Output to file                :  simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/out/RT_LS_pp_us_sa_rtvis_z26_wv40_oz30_cld0000.OUT
# Path to exec                :  /Users/dagoret/MacOSX/External/libRadtran/
# uvspec cmd:  /Users/dagoret/MacOSX/External/libRadtran/bin/uvspec  < simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/in/RT_LS_pp_us_sa_rtvis_z26_wv40_oz30_cld0000.INP > simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/out/RT_LS_pp_us_sa_rtvis_z26_wv40_oz30_cld0000.OUT
# simulate index = 17, airmass = 2.70
# --------------- ProcessSimulation -----------------------------
#  1) airmass =  2.7000000000000015
#  2) pwv =  4.0
#  3) oz =  300.0
#  4) pressure  =  0.0
#  5) atmospheric profile =  us
#  6) interaction processes =  sa
#  7) cloud extinction =  0
#  8) site or altitude =  LSST
# --------------------------------------------
# Dict_Of_sitesAltitudes.get(altitude_str) =  2.663
# Observation site altitude for libradran sim : 2.663 km
# Running uvspec with input file:  simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/in/RT_LS_pp_us_sa_rtvis_z27_wv40_oz30_cld0000.INP
# Output to file                :  simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/out/RT_LS_pp_us_sa_rtvis_z27_wv40_oz30_cld0000.OUT
# Path to exec                :  /Users/dagoret/MacOSX/External/libRadtran/
# uvspec cmd:  /Users/dagoret/MacOSX/External/libRadtran/bin/uvspec  < simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/in/RT_LS_pp_us_sa_rtvis_z27_wv40_oz30_cld0000.INP > simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/out/RT_LS_pp_us_sa_rtvis_z27_wv40_oz30_cld0000.OUT
# simulate index = 18, airmass = 2.80
# --------------- ProcessSimulation -----------------------------
#  1) airmass =  2.8000000000000016
#  2) pwv =  4.0
#  3) oz =  300.0
#  4) pressure  =  0.0
#  5) atmospheric profile =  us
#  6) interaction processes =  sa
#  7) cloud extinction =  0
#  8) site or altitude =  LSST
# --------------------------------------------
# Dict_Of_sitesAltitudes.get(altitude_str) =  2.663
# Observation site altitude for libradran sim : 2.663 km
# Running uvspec with input file:  simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/in/RT_LS_pp_us_sa_rtvis_z28_wv40_oz30_cld0000.INP
# Output to file                :  simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/out/RT_LS_pp_us_sa_rtvis_z28_wv40_oz30_cld0000.OUT
# Path to exec                :  /Users/dagoret/MacOSX/External/libRadtran/
# uvspec cmd:  /Users/dagoret/MacOSX/External/libRadtran/bin/uvspec  < simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/in/RT_LS_pp_us_sa_rtvis_z28_wv40_oz30_cld0000.INP > simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/out/RT_LS_pp_us_sa_rtvis_z28_wv40_oz30_cld0000.OUT
# simulate index = 19, airmass = 2.90
# --------------- ProcessSimulation -----------------------------
#  1) airmass =  2.9000000000000017
#  2) pwv =  4.0
#  3) oz =  300.0
#  4) pressure  =  0.0
#  5) atmospheric profile =  us
#  6) interaction processes =  sa
#  7) cloud extinction =  0
#  8) site or altitude =  LSST
# --------------------------------------------
# Dict_Of_sitesAltitudes.get(altitude_str) =  2.663
# Observation site altitude for libradran sim : 2.663 km
# Running uvspec with input file:  simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/in/RT_LS_pp_us_sa_rtvis_z29_wv40_oz30_cld0000.INP
# Output to file                :  simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/out/RT_LS_pp_us_sa_rtvis_z29_wv40_oz30_cld0000.OUT
# Path to exec                :  /Users/dagoret/MacOSX/External/libRadtran/
# uvspec cmd:  /Users/dagoret/MacOSX/External/libRadtran/bin/uvspec  < simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/in/RT_LS_pp_us_sa_rtvis_z29_wv40_oz30_cld0000.INP > simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/out/RT_LS_pp_us_sa_rtvis_z29_wv40_oz30_cld0000.OUT
# simulate index = 20, airmass = 3.00
# --------------- ProcessSimulation -----------------------------
#  1) airmass =  3.0000000000000018
#  2) pwv =  4.0
#  3) oz =  300.0
#  4) pressure  =  0.0
#  5) atmospheric profile =  us
#  6) interaction processes =  sa
#  7) cloud extinction =  0
#  8) site or altitude =  LSST
# --------------------------------------------
# Dict_Of_sitesAltitudes.get(altitude_str) =  2.663
# Observation site altitude for libradran sim : 2.663 km
# Running uvspec with input file:  simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/in/RT_LS_pp_us_sa_rtvis_z30_wv40_oz30_cld0000.INP
# Output to file                :  simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/out/RT_LS_pp_us_sa_rtvis_z30_wv40_oz30_cld0000.OUT
# Path to exec                :  /Users/dagoret/MacOSX/External/libRadtran/
# uvspec cmd:  /Users/dagoret/MacOSX/External/libRadtran/bin/uvspec  < simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/in/RT_LS_pp_us_sa_rtvis_z30_wv40_oz30_cld0000.INP > simulations/RT/2.0.5/LSST/pp/us/sa/rtvis/out/RT_LS_pp_us_sa_rtvis_z30_wv40_oz30_cld0000.OUT

# %%
for index in np.arange(NBOBS):   
    plt.semilogy(wl,all_trans[index],'-',color=all_colors[index])
plt.xlim(300,1200)
plt.grid()
plt.title(f"Atmospheric transmission for airmass from {AMMIN} to {AMMAX} by {AMSTEP} steps")
plt.xlabel("$\\lambda$ (nm)")
plt.ylabel("transmission")
plt.ylim(0.1,1)
figname="multitransmission_log.png"
plt.savefig(figname)

# %%
for index in np.arange(NBOBS):   
    plt.plot(wl,all_trans[index],'-',color=all_colors[index])
plt.xlim(300,1200)
plt.grid()
plt.title(f"Atmospheric transmission for airmass from {AMMIN} to {AMMAX} by {AMSTEP} steps")
plt.xlabel("$\\lambda$ (nm)")
plt.ylabel("transmission")
plt.ylim(0.0,1)
figname="multitransmission_lin.png"
plt.savefig(figname)
